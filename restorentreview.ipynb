# %% [markdown]
# <a href="https://colab.research.google.com/github/kamrulhasan04947/mlprac/blob/main/restorentreview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
labelencoder = preprocessing.LabelEncoder()

# %%
df = pd.read_csv("/content/drive/MyDrive/Restaurant reviews.csv")

# %%
df.head(10)
# Out:
#         Restaurant              Reviewer  \
# 0  Beyond Flavours     Rusha Chakraborty
# 1  Beyond Flavours  Anusha Tirumalaneedi
# 2  Beyond Flavours       Ashok Shekhawat
# 3  Beyond Flavours        Swapnil Sarkar
# 4  Beyond Flavours                Dileep
# 5  Beyond Flavours         Nagabhavani K
# 6  Beyond Flavours       Jamuna Bhuwalka
# 7  Beyond Flavours             Sandhya S
# 8  Beyond Flavours          Akash Thorat
# 9  Beyond Flavours        Smarak Patnaik
#
#                                               Review Rating  \
# 0  The ambience was good, food was quite good . h...      5
# 1  Ambience is too good for a pleasant evening. S...      5
# 2  A must try.. great food great ambience. Thnx f...      5
# 3  Soumen das and Arun was a great guy. Only beca...      5
# 4  Food is good.we ordered Kodi drumsticks and ba...      5
# 5  Ambiance is good, service is good, food is aPr...      5
# 6  Its a very nice place, ambience is different, ...      5
# ...

# %%
df.tail(10)
# Out:
#             Restaurant                 Reviewer  \
# 9990  Chinese Pavilion             Akram Ul Haq
# 9991  Chinese Pavilion  Krishna Teja Ratnakaram
# 9992  Chinese Pavilion               Sujay Garg
# 9993  Chinese Pavilion              Richard Rao
# 9994  Chinese Pavilion     Shiladitya Chaudhury
# 9995  Chinese Pavilion         Abhishek Mahajan
# 9996  Chinese Pavilion           Sharad Agrawal
# 9997  Chinese Pavilion                Ramandeep
# 9998  Chinese Pavilion          Nayana Shanbhag
# 9999  Chinese Pavilion         Bhargava Krishna
#
#                                                  Review Rating  \
# 9990  Amazing food ! I always go here when I want Ch...      5
# 9991  I was never a fan of Chinese food until I visi...      5
# 9992  I visited this restaurant with friends and was...      5
# 9993  Im going to cut to the chase, The food is exce...      5
# 9994  Chinese Pavilion in Banjara HIlls was the firs...    1.5
# ...

# %% [markdown]
# ## **Data Cleaning**

# %%
df.drop(["Review"], inplace=True, axis=1)

# %%
df.duplicated().sum()
# Out:
# 36

# %%
df.drop_duplicates(inplace=True)

# %%
df.isna().sum()
# Out:
# Restaurant    0
# Reviewer      2
# Rating        2
# Metadata      2
# Time          2
# Pictures      0
# dtype: int64

# %%
df.head()
# Out:
#         Restaurant              Reviewer Rating                 Metadata  \
# 0  Beyond Flavours     Rusha Chakraborty      5   1 Review , 2 Followers
# 1  Beyond Flavours  Anusha Tirumalaneedi      5  3 Reviews , 2 Followers
# 2  Beyond Flavours       Ashok Shekhawat      5  2 Reviews , 3 Followers
# 3  Beyond Flavours        Swapnil Sarkar      5    1 Review , 1 Follower
# 4  Beyond Flavours                Dileep      5  3 Reviews , 2 Followers
#
#               Time  Pictures
# 0  5/25/2019 15:54         0
# 1  5/25/2019 14:20         0
# 2  5/24/2019 22:54         0
# 3  5/24/2019 22:11         0
# 4  5/24/2019 21:37         0

# %% [markdown]
# **Feacher Enginerring**

# %% [markdown]
# **Restaurant fetcher**

# %%
#Count Restaurant
df.Restaurant.count()
# Out:
# 9964

# %%
#Total Restaurant
total_restaurant = len(df["Restaurant"].unique())
print(f"Total Restaurants are: {total_restaurant}")
# Out:
# Total Restaurants are: 100

# %%
#Label encoding for total restaurant
df["Restaurant"] = labelencoder.fit_transform(df["Restaurant"])

# %%
df.head(5)
# Out:
#    Restaurant              Reviewer Rating                 Metadata  \
# 0          16     Rusha Chakraborty      5   1 Review , 2 Followers
# 1          16  Anusha Tirumalaneedi      5  3 Reviews , 2 Followers
# 2          16       Ashok Shekhawat      5  2 Reviews , 3 Followers
# 3          16        Swapnil Sarkar      5    1 Review , 1 Follower
# 4          16                Dileep      5  3 Reviews , 2 Followers
#
#               Time  Pictures
# 0  5/25/2019 15:54         0
# 1  5/25/2019 14:20         0
# 2  5/24/2019 22:54         0
# 3  5/24/2019 22:11         0
# 4  5/24/2019 21:37         0

# %% [markdown]
# **Reviewer fetcher**

# %%
df.Reviewer.count()
# Out:
# 9962

# %%
total_reviewer = len(df["Reviewer"].unique())
print(f"Total reviewer is: {total_reviewer}")
# Out:
# Total reviewer is: 7447

# %%
df["Reviewer"] = labelencoder.fit_transform(df["Reviewer"])

# %%
df["Reviewer"].isna().sum()
# Out:
# 0

# %%
df.tail(5)
# Out:
#       Restaurant  Reviewer Rating                      Metadata  \
# 9995          20       167      3     53 Reviews , 54 Followers
# 9996          20      5631    4.5      2 Reviews , 53 Followers
# 9997          20      4625    1.5    65 Reviews , 423 Followers
# 9998          20      3591      4    13 Reviews , 144 Followers
# 9999          20      1182    3.5  472 Reviews , 1302 Followers
#
#                  Time  Pictures
# 9995    6/5/2016 0:08         0
# 9996   6/4/2016 22:01         0
# 9997   6/3/2016 10:37         3
# 9998  5/31/2016 17:22         0
# 9999  5/31/2016 16:41         6

# %%
unique_reviwer = df['Reviewer'].unique()
total_unique_reviewer = len(unique_reviwer)
print(f"Total unique rivewer is: {total_unique_reviewer}")
unique_reviwer
# Out:
# Total unique rivewer is: 7447
# array([4976,  766,  955, ..., 4625, 3591, 1182])

# %% [markdown]
# **Rating fetcher**

# %%
df.Rating.count()
# Out:
# 9962

# %%
df['Rating'].isna().sum()
# Out:
# 2

# %%
df['Rating'].dtype
# Out:
# dtype('O')

# %%
for i in range(df.shape[0]):
  if df['Rating'].isna().iloc[i]:
    print(i, end='___')
# Out:
# 8777___9063___

# %%
df[8776: 8779]
# Out:
#       Restaurant  Reviewer Rating                   Metadata             Time  \
# 8776           6      2428      5  2 Reviews , 166 Followers  10/7/2018 12:37
# 8777           6      7446    NaN                        NaN              NaN
# 8800          29      6876      1                  3 Reviews   5/18/2019 3:00
#
#       Pictures
# 8776         0
# 8777         0
# 8800         0

# %%
df[9062: 9065]
# Out:
#       Restaurant  Reviewer Rating                  Metadata             Time  \
# 9084           8      3916      5  18 Reviews , 7 Followers  2/25/2019 13:09
# 9085           8      7446    NaN                       NaN              NaN
# 9100          19      5284      5   1 Review , 11 Followers  5/25/2019 15:24
#
#       Pictures
# 9084         2
# 9085         0
# 9100         0

# %%
#removing null value
df['Rating'] = df['Rating'].apply(lambda x: x.replace("Like", "0") if x == "Like" else x)

# %%
df['Rating'].fillna(df["Rating"].apply(lambda x: float(x)).mean() , inplace=True)

# %%
df['Rating'].isna().sum()
# Out:
# 0

# %%
df['Rating'] = df['Rating'].apply(lambda x : float(x))

# %%
rating_unique_val = len(df['Rating'].unique())
rating_unique = df['Rating'].unique()
print(f"Rating unique value number:{rating_unique_val}\nRating unique value: {rating_unique}")
# Out:
# Rating unique value number:11
# Rating unique value: [5.         4.         1.         3.         2.         3.5
#  4.5        2.5        1.5        0.         3.60068259]

# %%
df[9062: 9065]
# Out:
#       Restaurant  Reviewer    Rating                  Metadata  \
# 9084           8      3916  5.000000  18 Reviews , 7 Followers
# 9085           8      7446  3.600683                       NaN
# 9100          19      5284  5.000000   1 Review , 11 Followers
#
#                  Time  Pictures
# 9084  2/25/2019 13:09         2
# 9085              NaN         0
# 9100  5/25/2019 15:24         0

# %%
df['Rating'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# **MataData fetcher**

# %%
df.Metadata.count()
# Out:
# 9962

# %%
total_matadata = len(df['Metadata'].unique())
print(f"Total number of Metadata: {total_matadata}")
print(f"Matadata: {df['Metadata'].unique()}")
# Out:
# Total number of Metadata: 2478
# Matadata: ['1 Review , 2 Followers' '3 Reviews , 2 Followers'
#  '2 Reviews , 3 Followers' ... '65 Reviews , 423 Followers'
#  '13 Reviews , 144 Followers' '472 Reviews , 1302 Followers']

# %%
df['Metadata'].isna().sum()
# Out:
# 2

# %%
df['Metadata'] = labelencoder.fit_transform(df['Metadata'])

# %%
df['Metadata'].isna().sum()
# Out:
# 0

# %%
df[9062: 9065]
# Out:
#       Restaurant  Reviewer    Rating  Metadata             Time  Pictures
# 9084           8      3916  5.000000       711  2/25/2019 13:09         2
# 9085           8      7446  3.600683      2477              NaN         0
# 9100          19      5284  5.000000        26  5/25/2019 15:24         0

# %% [markdown]
# **Time faeature**

# %%
df.Time.count()
# Out:
# 9962

# %%
unique_time = len(df['Time'].unique())
print(f"Unique Times : {unique_time}")
# Out:
# Unique Times : 9783

# %%
df['Time'].dtype
# Out:
# dtype('O')

# %%
df['Time'] = pd.to_datetime(df['Time'], format="%m/%d/%Y %H:%M")

# %%
df['Week_Day'] = df['Time'].dt.day_name()

# %%
df['Month_Name'] = df['Time'].dt.month_name()

# %%
df[9062: 9065]
# Out:
#       Restaurant  Reviewer    Rating  Metadata                Time  Pictures  \
# 9084           8      3916  5.000000       711 2019-02-25 13:09:00         2
# 9085           8      7446  3.600683      2477                 NaT         0
# 9100          19      5284  5.000000        26 2019-05-25 15:24:00         0
#
#       Week_Day Month_Name
# 9084    Monday   February
# 9085       NaN        NaN
# 9100  Saturday        May

# %%
#coping df to another df
analyzed_df1 = df.copy()

# %%
analyzed_df1.head(3)
# Out:
#    Restaurant  Reviewer  Rating  Metadata                Time  Pictures  \
# 0          16      4976     5.0        46 2019-05-25 15:54:00         0
# 1          16       766     5.0      1238 2019-05-25 14:20:00         0
# 2          16       955     5.0       792 2019-05-24 22:54:00         0
#
#    Week_Day Month_Name
# 0  Saturday        May
# 1  Saturday        May
# 2    Friday        May

# %%
#Cleaning un wanted columns
analyzed_df1.drop(['Time'], axis=1, inplace=True)

# %%
analyzed_df1.head(3)
# Out:
#    Restaurant  Reviewer  Rating  Metadata  Pictures  Week_Day Month_Name
# 0          16      4976     5.0        46         0  Saturday        May
# 1          16       766     5.0      1238         0  Saturday        May
# 2          16       955     5.0       792         0    Friday        May

# %%
#Rename column
'''analyzed_df1.rename(columns={'Week Day': 'Week_Day'}, inplace=True)
analyzed_df1.rename(columns={'Month Name': 'Month_Name'}, inplace= True)'''
# Out:
# "analyzed_df1.rename(columns={'Week Day': 'Week_Day'}, inplace=True)\nanalyzed_df1.rename(columns={'Month Name': 'Month_Name'}, inplace= True)"

# %% [markdown]
# **Week Day fetcher**

# %%
analyzed_df2 = analyzed_df1.copy()

# %%
analyzed_df2.head(3)
# Out:
#    Restaurant  Reviewer  Rating  Metadata  Pictures  Week_Day Month_Name
# 0          16      4976     5.0        46         0  Saturday        May
# 1          16       766     5.0      1238         0  Saturday        May
# 2          16       955     5.0       792         0    Friday        May

# %%
print(analyzed_df2.Week_Day.count())
analyzed_df2['Week_Day'].unique()
# Out:
# 9962
# array(['Saturday', 'Friday', 'Thursday', 'Wednesday', 'Tuesday', 'Monday',
#        'Sunday', nan], dtype=object)

# %%
analyzed_df2['Week_Day'] = labelencoder.fit_transform(analyzed_df2['Week_Day'])

# %%
analyzed_df2['Week_Day'].isna().sum()
# Out:
# 0

# %%
analyzed_df2.head(3)
# Out:
#    Restaurant  Reviewer  Rating  Metadata  Pictures  Week_Day Month_Name
# 0          16      4976     5.0        46         0         2        May
# 1          16       766     5.0      1238         0         2        May
# 2          16       955     5.0       792         0         0        May

# %% [markdown]
# **Month name fetcher**

# %%
print(analyzed_df2.Month_Name.count())
analyzed_df2['Month_Name'].unique()
# Out:
# 9962
# array(['May', 'April', 'March', 'February', 'January', 'December',
#        'November', 'October', 'September', 'August', 'July', 'June', nan],
#       dtype=object)

# %%
analyzed_df2['Month_Name'] = labelencoder.fit_transform(analyzed_df2['Month_Name'])

# %%
analyzed_df2['Month_Name'].isna().sum()
# Out:
# 0

# %%
analyzed_df2.head(3)
# Out:
#    Restaurant  Reviewer  Rating  Metadata  Pictures  Week_Day  Month_Name
# 0          16      4976     5.0        46         0         2           8
# 1          16       766     5.0      1238         0         2           8
# 2          16       955     5.0       792         0         0           8

# %% [markdown]
# **Pictures Feature**

# %%
analyzed_df2.Pictures.count()
# Out:
# 9964

# %%
analyzed_df2['Pictures'].unique()
# Out:
# array([ 0,  8,  1,  7,  2,  6,  3,  5,  9,  4, 16, 26, 10, 15, 22, 11, 14,
#        13, 21, 52, 18, 20, 27, 19, 12, 41, 42, 37, 28, 17, 25, 24, 34, 64,
#        23, 32])

# %%
analyzed_df2['Pictures'].isna().sum()
# Out:
# 0

# %% [markdown]
# **Feature Scaling**

# %%
scaler = preprocessing.MinMaxScaler()
data_scaler_M = scaler.fit_transform(analyzed_df2)
data_scaled_M = pd.DataFrame(data_scaler_M, columns=analyzed_df2.columns)

# %%
scaler1 = preprocessing.RobustScaler()
data_scaler_r = scaler1.fit_transform(analyzed_df2)
data_scaled_r = pd.DataFrame(data_scaler_M, columns=analyzed_df2.columns)

# %%
scaler2 = preprocessing.StandardScaler()
data_scaler_s = scaler2.fit_transform(analyzed_df2)
data_scaled_s = pd.DataFrame(data_scaler_M, columns=analyzed_df2.columns)

# %%
# discrived data by MinMax Scler
data_scaled_M.describe().T
# Out:
#              count      mean       std  min       25%       50%       75%  max
# Restaurant  9964.0  0.501559  0.290959  0.0  0.252525  0.505051  0.757576  1.0
# Reviewer    9964.0  0.496959  0.289308  0.0  0.244259  0.498724  0.748086  1.0
# Rating      9964.0  0.720137  0.296735  0.0  0.600000  0.800000  1.000000  1.0
# Metadata    9964.0  0.377036  0.313276  0.0  0.033508  0.315301  0.633024  1.0
# Pictures    9964.0  0.011739  0.040229  0.0  0.000000  0.000000  0.000000  1.0
# Week_Day    9964.0  0.413632  0.275632  0.0  0.142857  0.428571  0.571429  1.0
# Month_Name  9964.0  0.446257  0.284597  0.0  0.166667  0.416667  0.666667  1.0

# %%
#Show by Robust Scaler
data_scaled_r.describe().T
# Out:
#              count      mean       std  min       25%       50%       75%  max
# Restaurant  9964.0  0.501559  0.290959  0.0  0.252525  0.505051  0.757576  1.0
# Reviewer    9964.0  0.496959  0.289308  0.0  0.244259  0.498724  0.748086  1.0
# Rating      9964.0  0.720137  0.296735  0.0  0.600000  0.800000  1.000000  1.0
# Metadata    9964.0  0.377036  0.313276  0.0  0.033508  0.315301  0.633024  1.0
# Pictures    9964.0  0.011739  0.040229  0.0  0.000000  0.000000  0.000000  1.0
# Week_Day    9964.0  0.413632  0.275632  0.0  0.142857  0.428571  0.571429  1.0
# Month_Name  9964.0  0.446257  0.284597  0.0  0.166667  0.416667  0.666667  1.0

# %%
#Show by Standerdazition
data_scaled_s.describe().T
# Out:
#              count      mean       std  min       25%       50%       75%  max
# Restaurant  9964.0  0.501559  0.290959  0.0  0.252525  0.505051  0.757576  1.0
# Reviewer    9964.0  0.496959  0.289308  0.0  0.244259  0.498724  0.748086  1.0
# Rating      9964.0  0.720137  0.296735  0.0  0.600000  0.800000  1.000000  1.0
# Metadata    9964.0  0.377036  0.313276  0.0  0.033508  0.315301  0.633024  1.0
# Pictures    9964.0  0.011739  0.040229  0.0  0.000000  0.000000  0.000000  1.0
# Week_Day    9964.0  0.413632  0.275632  0.0  0.142857  0.428571  0.571429  1.0
# Month_Name  9964.0  0.446257  0.284597  0.0  0.166667  0.416667  0.666667  1.0

# %% [markdown]
# **data visualization**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(data_scaled_r.corr(), annot=True, cmap='viridis', cbar=True)
# Out:
# <Axes: >

# %%
data_scaled_r['Reviewer'].plot(kind='box')
# Out:
# <Axes: >

# %%
data_scaled_r['Restaurant'].plot(kind='box')
# Out:
# <Axes: >

# %%
data_scaled_r['Rating'].plot(kind='box')
# Out:
# <Axes: >

# %%
sns.scatterplot(data=data_scaled_r, x="Restaurant", y="Rating", hue="Reviewer")
# Out:
# <Axes: xlabel='Restaurant', ylabel='Rating'>

# %%
plt.scatter(x="Reviewer", y="Rating")

# %%
plt.scatter(x="Restaurant", y="Rating")

# %%
data_scaled_r.hist(color='green', alpha=0.5, stat='density' figsize=(8,8))
# Out:
#   File "<ipython-input-1-d2484f518808>", line 1
#     data_scaled_r.hist(color='green', alpha=0.5, stat='density' figsize=(8,8))
#                                                       ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# **Training and Testing**

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import  GaussianNB

# %%
x = data_scaler_s.drop(["Rating"], axis=1)
y= data_scaler_s.Rating
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7b4d4e32cc74> in <cell line: 1>()
# ----> 1 x = data_scaler_s.drop(["Rating"], axis=1)
#       2 y= data_scaler_s.Rating
#
# NameError: name 'data_scaler_s' is not defined

# %%
x.head(3)
# Out:
#    Restaurant  Reviewer  Metadata  Pictures  Week_Day  Month_Name
# 0    0.161616  0.668278  0.018571       0.0  0.285714    0.666667
# 1    0.161616  0.102874  0.499798       0.0  0.285714    0.666667
# 2    0.161616  0.128257  0.319742       0.0  0.000000    0.666667

# %%
y
# Out:
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
#        ...
# 9959    0.6
# 9960    0.9
# 9961    0.3
# 9962    0.8
# 9963    0.7
# Name: Rating, Length: 9964, dtype: float64

# %%
y = labelencoder.fit_transform(y)
x['Pictures'] = labelencoder.fit_transform(x['Pictures'])

# %%
x.head(3)
# Out:
#    Restaurant  Reviewer  Metadata  Pictures  Week_Day  Month_Name
# 0    0.161616  0.668278  0.018571         0  0.285714    0.666667
# 1    0.161616  0.102874  0.499798         0  0.285714    0.666667
# 2    0.161616  0.128257  0.319742         0  0.000000    0.666667

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25 )
NB_model = GaussianNB()
NB_classifier = NB_model.fit(x_train, y_train)
NB_prediction = NB_classifier.predict(x_test)
from sklearn.metrics import classification_report, confusion_matrix
CM = confusion_matrix(y_test, NB_prediction)
print("confusion matrix:\n", CM)
CR=classification_report(y_test, NB_prediction)
print("performance: \n", CR)
# Out:
# confusion matrix:
#  [[392   0   0   0   0   0   3   0  24]
#  [  1   0   0   0   0   0   0   0   0]
#  [146   0   0   0   0   0   6   0  20]
#  [  1   0   0   0   0   0   0   0   0]
#  [259   0   0   0   0   0  50   0  29]
#  [  6   0   0   0   0   0   3   0   3]
#  [387   0   0   0   0   0 109   0  95]
#  [  6   0   0   0   0   0   1   0   4]
#  [793   0   0   0   0   0  68   0  85]]
# performance:
#                precision    recall  f1-score   support
#
#            1       0.20      0.94      0.33       419
#            2       0.00      0.00      0.00         1
#            3       0.00      0.00      0.00       172
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00       338
#            6       0.00      0.00      0.00        12
#            8       0.45      0.18      0.26       591
#            9       0.00      0.00      0.00        11
#           10       0.33      0.09      0.14       946
#
# ...

# %%
true_positive = CM[0][0]
false_positive = CM[0][1]
false_negative = CM[1][0]
true_negative = CM[1][1]
